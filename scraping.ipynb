# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def fetch_articles(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    articles_section = soup.find('div',)

# %%
url = 'https://world-nuclear-news.org/search.aspx?searchtext=smr'
#url = 'https://www.britannica.com/topic/nuclear-proliferation'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

urls = []

for link in soup.find_all('a'):
    tmp = link.get('href')
    #if 'Article' in tmp:
    urls.append(tmp)

for u in urls:
    print(u)
# Out:
# /Cookies-Policy
# /Privacy-Notice
# /Cookies-Policy
# /
# http://members.world-nuclear.org/iMIS20/WNA/Newsletter_Subscription/Select_Subscription_Options.aspx
# /About-us
# /contactwnn.html
# /Energy-Environment
# /New-Nuclear
# /Regulation-Safety
# /Nuclear-Policies
# /Corporate
# /Uranium-Fuel
# /Waste-Recycling
# /Perspectives
# #
# /Articles/Westinghouse-ready-to-make-SMR-fuel-in-UK
# /Articles/Westinghouse-SMR-progress-slows
# /Articles/Fortum-and-MIT-launch-SMR-modelling-project
# /Articles/Australian-SMR-feasible-by-2030
# /Articles/B-W-contracts-for-SMR-forgings
# /Articles/US-consortium-calls-for-public-private-SMR-support
# /Articles/Westinghouse-gets-approval-for-SMR-testing
# /Articles/UK-SMR-consortium-calls-for-government-support
# javascript:__doPostBack('ctl00$ContentPlaceHolder1$PlaceHolderZones$lt$SearchResults$SmartSearchResults$srchResults$pgrSearch','1')
# ...

# %%
url = 'https://world-nuclear-news.org/Articles/Westinghouse-ready-to-make-SMR-fuel-in-UK'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

print(soup.find_all)
# Out:
# <bound method Tag.find_all of <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width, initial-scale=1" name="viewport"/><title>
# 	Westinghouse ready to make SMR fuel in UK - World Nuclear News
# </title>
# <!-- Bootstrap CSS -->
# <link href="/CMSPages/GetResource.ashx?stylesheetfile=/css/bootstrap.min.css" rel="stylesheet"/><link href="/CMSPages/GetResource.ashx?stylesheetfile=/css/font-awesome.min.css" rel="stylesheet"/>
# <!-- Adaptive site specific CSS -->
# <link href="/CMSPages/GetResource.ashx?stylesheetname=adaptive" rel="stylesheet"/>
# <!-- Adaptive CSSs -->
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!--[if lt IE 9]>
#         <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#         <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
# ...

# %%
# Out:
# ['/Cookies-Policy', '/Privacy-Notice', '/Cookies-Policy', '/', 'http://members.world-nuclear.org/iMIS20/WNA/Newsletter_Subscription/Select_Subscription_Options.aspx', '/About-us', '/contactwnn.html', '/Energy-Environment', '/New-Nuclear', '/Regulation-Safety', '/Nuclear-Policies', '/Corporate', '/Uranium-Fuel', '/Waste-Recycling', '/Perspectives', '#', '/Articles/Westinghouse-ready-to-make-SMR-fuel-in-UK', '/Articles/Westinghouse-SMR-progress-slows', '/Articles/Fortum-and-MIT-launch-SMR-modelling-project', '/Articles/Australian-SMR-feasible-by-2030', '/Articles/B-W-contracts-for-SMR-forgings', '/Articles/US-consortium-calls-for-public-private-SMR-support', '/Articles/Westinghouse-gets-approval-for-SMR-testing', '/Articles/UK-SMR-consortium-calls-for-government-support', "javascript:__doPostBack('ctl00$ContentPlaceHolder1$PlaceHolderZones$lt$SearchResults$SmartSearchResults$srchResults$pgrSearch','1')", "javascript:__doPostBack('ctl00$ContentPlaceHolder1$PlaceHolderZones$lt$SearchResu
# ...
